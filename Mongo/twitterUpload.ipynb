# %%
import pymongo
import json

# %%
conn = "mongodb+srv://project3app:mongo1@cluster0.khzagou.mongodb.net/?retryWrites=true&w=majority"

# %%
import pickle
with open('../Twitter/twitterData', 'rb') as json_file:
    data = pickle.load(json_file)

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
matching_list = []
with pymongo.MongoClient(conn) as client:
    db = client.natparkapp
    geo_coll = db.geojson
    twit_coll = db.twitterData

# %%
usernames = []
parknames = []
for twitter_park in data:
    twitter_name = twitter_park['park']['username']
    usernames.append(twitter_name)

# %%
with open('../../parks personal/parks.geojson', 'r') as geo_file:
    geo_data = json.load(geo_file)
    print(type(geo_data['features']))
    geo_list = geo_data['features']
    # for geo_park in geo_file:
    #     geo_name = geo_park['parkname']
    #     parknames.append(geo_name)
# Out:
# <class 'list'>

# %%
for park in geo_list:
   geo_name = park['properties']['PARKNAME']
   parknames.append(geo_name)

# %%
print(usernames[1][0:6] in parknames[1])
print(parknames)
# Out:
# False
# ...

# %%
names_list = []
for username in usernames:
    ratio = 0
    for parkname in parknames:
        try:
            temp_ratio = similar(username,parkname)
            if temp_ratio > ratio:
                ratio = temp_ratio
                temp_dict = {
                    'match_strength':ratio,
                    'twitter':username,
                    'park':parkname
                    }
        except:
            pass
    # done iterating through all parknames
    if temp_dict['match_strength'] > 0.75:
        names_list.append(temp_dict)
    else:
        temp_dict = {
            'match_strength':ratio,
            'twitter':username,
            'park':None
            }
        names_list.append(temp_dict)

# %%
from pprint import pprint
# pprint(names_list)
with open('../../parks personal/Twitter/matching.json','w') as file:
    json.dump(names_list, file)

# %%
for user in data:
    for name in names_list:
        if user['park']['username'] == name['twitter']:
# Out:
# [{'park': {'username': 'AcadiaNPS', 'id': '185874758'},
#   'mentionData': {'data': [{'edit_history_tweet_ids': ['1615400032387178498'],
#      'id': '1615400032387178498',
#      'text': '@paperthynn @SonyAlpha @moment @peaksdesign @visitmaine @AcadiaNPS gmmg Joshua!'},
#     {'edit_history_tweet_ids': ['1615397549959155712'],
#      'id': '1615397549959155712',
#      'text': '@paperthynn @SonyAlpha @moment @peaksdesign @visitmaine @AcadiaNPS gm Joshua'},
#     {'edit_history_tweet_ids': ['1615388213228752900'],
#      'id': '1615388213228752900',
#      'text': '@paperthynn @SonyAlpha @moment @peaksdesign @visitmaine @AcadiaNPS I wish someone would carry me on hikes 🤣'},
#     {'edit_history_tweet_ids': ['1615387029457494016'],
#      'id': '1615387029457494016',
#      'text': '@GeekNYWoo @SonyAlpha @moment @peaksdesign @visitmaine @AcadiaNPS going to be dragging him along soon enough 😂'},
#     {'edit_history_tweet_ids': ['1615386736321855488'],
# ...

# %%
with pymongo.MongoClient(conn) as client:
    with open('../../parks personal/Twitter/matching.json','r') as names_list:
        for name in names_list:
            client.twitterKeys.insert_one(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 4
#       2 with open('../../parks personal/Twitter/matching.json','r') as names_list:
#       3     for name in names_list:
# ----> 4         client.twitterKeys.insert_one(name)
#
# File c:\Users\e1317395\Anaconda3\envs\natparkapp\lib\site-packages\pymongo\collection.py:3480, in Collection.__call__(self, *args, **kwargs)
#    3477 """This is only here so that some API misusages are easier to debug.
#    3478 """
#    3479 if "." not in self.__name:
# -> 3480     raise TypeError("'Collection' object is not callable. If you "
#    3481                     "meant to call the '%s' method on a 'Database' "
#    3482                     "object it is failing because no such method "
#    3483                     "exists." %
#    3484                     self.__name)
# ...
